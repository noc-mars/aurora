# %%
import cv2
path_raw = "D:\\berna\\Progetti\\ocean-data\\Test1.raw"
path_png = "D:\\berna\\Progetti\\ocean-data\\result.png"
col = 2448
row = 2048

with open(path_raw, "rb") as rawimg:
   img = np.fromfile(rawimg, np.dtype('u1'), col * row).reshape(row, col)
   img.tofile(path_raw)
   colimg = cv2.cvtColor(img, cv2.COLOR_BAYER_GB2RGB)
   cv2.imwrite(path_png, colimg)

IMAGE = colour.io.read_image(path_png);
plot_image(IMAGE);
